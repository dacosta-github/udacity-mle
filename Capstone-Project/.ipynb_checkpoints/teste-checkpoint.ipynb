# %%
import os
import requests
import zipfile



def download(url: str, dest_folder: str, unzip: int):
    if not os.path.exists(dest_folder):
        os.makedirs(dest_folder)  # create folder if it does not exist

    filename = url.split('/')[-1].replace(" ", "_")  # be careful with file names
    file_path = os.path.join(dest_folder, filename)
    
    r = requests.get(url, stream=True)
    unique_file_path = os.path.abspath(file_path)
    if r.ok:
        print("saving to", os.path.abspath(file_path))
        with open(file_path, 'wb') as f:
            for chunk in r.iter_content(chunk_size=1024 * 8):
                if chunk:
                    f.write(chunk)
                    f.flush()
                    os.fsync(f.fileno())
    else:  # HTTP status code 4XX/5XX
        print("Download failed: status code {}\n{}".format(r.status_code, r.text))
    
    if unzip==1:
        with zipfile.ZipFile(unique_file_path, "r") as z:
            z.extractall(os.path.join(dest_folder))
    else:  
        print("jump")
        
    a="complaints.csv"
    return a

# %%
file=download("https://files.consumerfinance.gov/ccdb/complaints.csv.zip", dest_folder="dataset", unzip=1)
# Out:
# saving to /Users/sergio.dacosta/Documents/_github/udacity-mle/Capstone-Project/dataset/complaints.csv.zip

# %%
with zipfile.ZipFile('/Users/sergio.dacosta/Documents/_github/udacity-mle/Capstone-Project/dataset/complaints.csv.zip', "r") as z:
    z.extractall("/Users/sergio.dacosta/Documents/_github/udacity-mle/Capstone-Project/dataset/")

# %%
import pandas as pd
import numpy as np
file = '/Users/sergio.dacosta/Documents/_github/udacity-mle/Capstone-Project/dataset/complaints.csv'
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
df = pd.read_csv(os.path.abspath(file))

# %%
df.head()
# Out:
#   Date received                                            Product  \
# 0    2020-10-24  Credit reporting, credit repair services, or o...
# 1    2019-09-24                                    Debt collection
# 2    2019-09-19  Credit reporting, credit repair services, or o...
# 3    2019-11-08                                    Debt collection
# 4    2020-10-27  Credit reporting, credit repair services, or o...
#
#         Sub-product                                 Issue  \
# 0  Credit reporting           Improper use of your report
# 1     I do not know     Attempts to collect debt not owed
# 2  Credit reporting  Incorrect information on your report
# 3     I do not know                 Communication tactics
# 4  Credit reporting  Incorrect information on your report
#
#                                            Sub-issue  \
# 0  Credit inquiries on your report that you don't...
# 1                                  Debt is not yours
# ...

# %%
import sweetviz as sv

my_report = sv.analyze(df)
my_report.show_html() # Default arguments will generate to "SWEETVIZ_REPORT.html"
# Out:
# :FEATURES DONE:                    |                     | [  0%]   00:18  -> (00:00 left)
# :PAIRWISE DONE:                    |█████████████████████| [100%]   01:51  -> (00:00 left)
# Creating Associations graph... DONE!

# %%
from io import StringIO
col = ['Product', 'Consumer complaint narrative']
df = df[col]
df = df[pd.notnull(df['Consumer complaint narrative'])]
df.columns = ['Product', 'Consumer_complaint_narrative']
df['category_id'] = df['Product'].factorize()[0]
category_id_df = df[['Product', 'category_id']].drop_duplicates().sort_values('category_id')
category_to_id = dict(category_id_df.values)
id_to_category = dict(category_id_df[['category_id', 'Product']].values)
df.head()
# Out:
#                                              Product  \
# 1                                    Debt collection
# 3                                    Debt collection
# 6                                    Debt collection
# 8  Credit reporting, credit repair services, or o...
# 9  Credit reporting, credit repair services, or o...
#
#                         Consumer_complaint_narrative  category_id
# 1  transworld systems inc. \nis trying to collect...            0
# 3  Over the past 2 weeks, I have been receiving e...            0
# 6  Pioneer has committed several federal violatio...            0
# 8  Previously, on XX/XX/XXXX, XX/XX/XXXX, and XX/...            1
# 9  Hello This complaint is against the three cred...            1

# %%
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(8,6))
df.groupby('Product').Consumer_complaint_narrative.count().plot.bar(ylim=0)
plt.show()

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf = TfidfVectorizer(sublinear_tf=True, min_df=5, norm='l2', encoding='latin-1', ngram_range=(1, 2), stop_words='english')
features = tfidf.fit_transform(df.Consumer_complaint_narrative).toarray()
labels = df.category_id
features.shape
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-173-97e32167d120> in <module>
#       1 from sklearn.feature_extraction.text import TfidfVectorizer
#       2 tfidf = TfidfVectorizer(sublinear_tf=True, min_df=5, norm='l2', encoding='latin-1', ngram_range=(1, 2), stop_words='english')
# ----> 3 features = tfidf.fit_transform(df.Consumer_complaint_narrative).toarray()
#       4 labels = df.category_id
#       5 features.shape
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/sklearn/feature_extraction/text.py in fit_transform(self, raw_documents, y)
#    1650         """
#    1651         self._check_params()
# -> 1652         X = super().fit_transform(raw_documents)
#    1653         self._tfidf.fit(X)
#    1654         # X is already a transformed view of raw_documents so
#
# ...

# %%
from sklearn.feature_selection import chi2
import numpy as np
N = 2
for Product, category_id in sorted(category_to_id.items()):
    features_chi2 = chi2(features, labels == category_id)
    indices = np.argsort(features_chi2[0])
    feature_names = np.array(tfidf.get_feature_names())[indices]
    unigrams = [v for v in feature_names if len(v.split(' ')) == 1]
    bigrams = [v for v in feature_names if len(v.split(' ')) == 2]
    print("# '{}':".format(Product))
    print("  . Most correlated unigrams:\n. {}".format('\n. '.join(unigrams[-N:])))
    print("  . Most correlated bigrams:\n. {}".format('\n. '.join(bigrams[-N:])))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-174-619bcff25545> in <module>
#       3 N = 2
#       4 for Product, category_id in sorted(category_to_id.items()):
# ----> 5     features_chi2 = chi2(features, labels == category_id)
#       6     indices = np.argsort(features_chi2[0])
#       7     feature_names = np.array(tfidf.get_feature_names())[indices]
#
# NameError: name 'features' is not defined
